# %% [markdown]
# <a href="https://colab.research.google.com/github/PosgradoMNA/actividades-del-projecto-equipo-19/blob/main/project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Stock price CEMEX
# * Range data to analize: 20 september 2012 to 20 september 2022

# %% [markdown]
#  ### Generated by: *Yahoo! finance*
# * Download Link: <a href="https://query1.finance.yahoo.com/v7/finance/download/CEMEXCPO.MX?period1=1348099200&period2=1663632000&interval=1d&events=history&includeAdjustedClose=true" target="_blank">CEMEX Dataset</a>

# %% [markdown]
# ### Brief description of the data:
#
# *The data set contains the historical closing price of the Mexican stock "CEMEX", from September 20, 2012 to September 20, 2022.*

# %% [markdown]
# ### Related questions for the data:
# 1. How does inflation rate affect the stock price?
# 2. In which presidential term has the stock performed best?
# 3. Is there any stock of any direct competitor that has a negative correlation?
# 4. Has the stock represented earnings over the last 10 years?
# 5. What effect does unemployment have on the share price?
# 6. What is the relationship between share price and gross domestic product?
# 7. What economic/macroeconomic factors have the greatest influence on the share price?
# 8. What will the share price be the following month?

# %% [markdown]
# ### Who's interested for this analysis?
# - *Potential investors on buying stocks from CEMEX*
# - *Current investors*
